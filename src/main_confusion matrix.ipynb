# %%
import torch
import numpy as np
import os

from sklearn.metrics import confusion_matrix
from utils import get_ecg, qrs_detection, get_segments, plot, plot_confusion_matrix
from data import build_dataloader
from train import learn, cnn_feed_lstm

# %%
PATH = "/Users/nguyenvietthai/Downloads/training2017"
BATCH_SIZE = 2048
EPOCH = 5
FS = 300
LENGTH = 9000
LR = 1e-3
RESAMP = False

# %%
try:
    segments = np.load('/Users/nguyenvietthai/Downloads/training2017/segment.npy')
except:
    signals, labels = get_ecg(PATH, length=LENGTH)
    segments = np.zeros((245990, 1001))
    k = 0
    
    for i, record in enumerate(signals):
        print("running",i)
        rp = qrs_detection(record, sample_rate=FS)
        seg = get_segments(record, rp, labels[i])
        if seg is not None:
            segments[k:k+seg.shape[0], :] = seg
            k += seg.shape[0]
    del signals, labels
    
    np.save('/Users/nguyenvietthai/Downloads/training2017/segment.npy', segments)

# %%
X, y = segments[:, :-1], segments[:, -1][:, np.newaxis]
del segments

train, test = build_dataloader(X, y, resamp=RESAMP, batch_size=BATCH_SIZE)
del X, y

net = cnn_feed_lstm()
try:
    params = torch.load("../params/net_0.81.pkl")
    net.load_state_dict(params["model_state_dict"])
except:
    pass
# Out:
# Start building dataloader.

# %%
loss, val_score, predictions, true_labels = learn(net, train, test, lr=LR, epoch=EPOCH)
plot(loss, val_score)
# Out:
# Start training.
# Epoch:  1  | Loss: 0.684  | F1 Score: 0.74
#               precision    recall  f1-score   support
#
#         aFib       0.70      0.50      0.58      3997
#       Normal       0.77      0.92      0.84     20943
#       Others       0.66      0.50      0.57     11959
#
#     accuracy                           0.74     36899
#    macro avg       0.71      0.64      0.66     36899
# weighted avg       0.73      0.74      0.72     36899
#
# Epoch:  2  | Loss: 0.665  | F1 Score: 0.75
#               precision    recall  f1-score   support
#
#         aFib       0.72      0.59      0.65      3997
#       Normal       0.77      0.93      0.84     20943
#       Others       0.72      0.49      0.58     11959
#
#     accuracy                           0.75     36899
#    macro avg       0.74      0.67      0.69     36899
# weighted avg       0.75      0.75      0.74     36899
#
# Epoch:  3  | Loss: 0.614  | F1 Score: 0.76
#               precision    recall  f1-score   support
#
#         aFib       0.77      0.58      0.66      3997
#       Normal       0.77      0.93      0.84     20943
#       Others       0.71      0.52      0.60     11959
#
#     accuracy                           0.76     36899
#    macro avg       0.75      0.68      0.70     36899
# weighted avg       0.75      0.76      0.75     36899
#
# Epoch:  4  | Loss: 0.510  | F1 Score: 0.77
#               precision    recall  f1-score   support
#
#         aFib       0.75      0.60      0.67      3997
#       Normal       0.78      0.94      0.85     20943
#       Others       0.74      0.52      0.61     11959
#
#     accuracy                           0.77     36899
#    macro avg       0.76      0.69      0.71     36899
# weighted avg       0.76      0.77      0.75     36899
#
# Epoch:  5  | Loss: 0.535  | F1 Score: 0.77
#               precision    recall  f1-score   support
#
#         aFib       0.76      0.64      0.69      3997
#       Normal       0.79      0.92      0.85     20943
#       Others       0.72      0.56      0.63     11959
#
#     accuracy                           0.77     36899
#    macro avg       0.76      0.71      0.73     36899
# weighted avg       0.77      0.77      0.76     36899
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File /Users/nguyenvietthai/Downloads/ECG-Signal-Analysis-master/src/main.py:2
#       1 #%%
# ----> 2 loss, val_score, predictions, true_labels = learn(net, train, test, lr=LR, epoch=EPOCH)
#       3 plot(loss, val_score)
#
# File ~/Downloads/ECG-Signal-Analysis-master/src/train.py:165, in learn(net, train, test, lr, epoch)
#     163 choice = input("Save or not?[y/n]")
#     164 if choice == 'y':
# --> 165     torch.save({'model_state_dict': net.state_dict()}, "../params/net_params.pkl")
#     167 return np.array(loss_data), np.array(val_score), np.array(y_pred), np.array(y_true)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/serialization.py:618, in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization, _disable_byteorder_record)
#     615 _check_save_filelike(f)
#     617 if _use_new_zipfile_serialization:
# --> 618     with _open_zipfile_writer(f) as opened_zipfile:
#     619         _save(obj, opened_zipfile, pickle_module, pickle_protocol, _disable_byteorder_record)
#     620         return
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/serialization.py:492, in _open_zipfile_writer(name_or_buffer)
#     490 else:
#     491     container = _open_zipfile_writer_buffer
# --> 492 return container(name_or_buffer)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/serialization.py:463, in _open_zipfile_writer_file.__init__(self, name)
#     461     super().__init__(torch._C.PyTorchFileWriter(self.file_stream))
#     462 else:
# --> 463     super().__init__(torch._C.PyTorchFileWriter(self.name))
#
# RuntimeError: Parent directory ../params does not exist.

# %%
loss, val_score, predictions, true_labels = learn(net, train, test, lr=LR, epoch=EPOCH)
plot(loss, val_score)
# Out:
# Start training.
# Epoch:  1  | Loss: 0.505  | F1 Score: 0.77
#               precision    recall  f1-score   support
#
#         aFib       0.79      0.62      0.69      3997
#       Normal       0.78      0.93      0.85     20943
#       Others       0.74      0.54      0.63     11959
#
#     accuracy                           0.77     36899
#    macro avg       0.77      0.70      0.72     36899
# weighted avg       0.77      0.77      0.76     36899
#
# Epoch:  2  | Loss: 0.640  | F1 Score: 0.78
#               precision    recall  f1-score   support
#
#         aFib       0.73      0.69      0.71      3997
#       Normal       0.79      0.93      0.85     20943
#       Others       0.76      0.53      0.62     11959
#
#     accuracy                           0.78     36899
#    macro avg       0.76      0.72      0.73     36899
# weighted avg       0.77      0.78      0.76     36899
#
# Epoch:  3  | Loss: 0.534  | F1 Score: 0.77
#               precision    recall  f1-score   support
#
#         aFib       0.72      0.71      0.72      3997
#       Normal       0.78      0.94      0.85     20943
#       Others       0.78      0.50      0.61     11959
#
#     accuracy                           0.77     36899
#    macro avg       0.76      0.72      0.73     36899
# weighted avg       0.77      0.77      0.76     36899
#
# Epoch:  4  | Loss: 0.534  | F1 Score: 0.78
#               precision    recall  f1-score   support
#
#         aFib       0.76      0.67      0.71      3997
#       Normal       0.79      0.93      0.86     20943
#       Others       0.76      0.54      0.63     11959
#
#     accuracy                           0.78     36899
#    macro avg       0.77      0.72      0.73     36899
# weighted avg       0.78      0.78      0.77     36899
#
# Epoch:  5  | Loss: 0.422  | F1 Score: 0.78
#               precision    recall  f1-score   support
#
#         aFib       0.78      0.65      0.71      3997
#       Normal       0.78      0.95      0.86     20943
#       Others       0.78      0.53      0.63     11959
#
#     accuracy                           0.78     36899
#    macro avg       0.78      0.71      0.73     36899
# weighted avg       0.78      0.78      0.77     36899
#
# The average validation score is: 0.78

# %%
cm = confusion_matrix(true_labels,predictions)
classes = ['aFib','Normal','Others']

# Plot the confusion matrix
plot_confusion_matrix(cm, classes, normalize=True, title='Confusion Matrix, Normalized')
# Out:
# Normalized confusion matrix
